# %%
import ipywidgets as widgets

class Menu:
    def __init__(self):
        self.out = widgets.Output()        
        self.btnMain = widgets.Button(description = "Go To Main", layout=widgets.Layout(width='120px'))
        self.btnClient = widgets.Button(description = "Go To Client", layout=widgets.Layout(width='120px'))
        self.btnTask = widgets.Button(description = "Go To Task", layout=widgets.Layout(width='120px'))
        self.btnEditRecord = widgets.Button(description = "Edit Record", layout=widgets.Layout(width='120px'))
        self.btnClearOutput = widgets.Button(description = "Clear Output", layout=widgets.Layout(width='120px'))
        self.btnSaveUpdate = widgets.Button(description = 'Save Update', layout=widgets.Layout(width='120px'))

        self.siteMenu = widgets.HBox([self.btnMain, self.btnClient, self.btnTask,\
                                      self.btnClearOutput, self.btnEditRecord])
        
        with self.out:
            display(self.siteMenu)

        def btnMainClicked(b):
            self.out.clear_output(wait=True)
            menu.out.clear_output(wait=True)
            with self.out:
                display(self.siteMenu)
                
        def btnNewClient(b):
            with self.out:
                client = Client()
                
        def btnNewTask(b):
            with self.out:
                task = Task()                

        self.btnMain.on_click(btnMainClicked)
        self.btnClient.on_click(btnNewClient)
        self.btnTask.on_click(btnNewTask)
        
        self.out
        
        
class Client:
    def __init__(self):
        self.out = widgets.Output()
        self.btnClient = widgets.Button(description = "btnClient", layout=widgets.Layout(width='120px'))
        self.btnNewLine = widgets.Button(description = "New Line", layout=widgets.Layout(width='120px'))
        self.btnListRecords = widgets.Button(description = "List Records", layout=widgets.Layout(width='120px'))        
        self.btnClearOutput = widgets.Button(description = "Clear Output", layout=widgets.Layout(width='120px'))
        self.btnEditRecord = widgets.Button(description = "Edit Record", layout=widgets.Layout(width='120px'))
        
        self.clientMenu = widgets.HBox([self.btnClient, self.btnNewLine, self.btnListRecords,\
                                       self.btnClearOutput, self.btnEditRecord])
        
        with menu.out:
            menu.out.clear_output(wait=True)
            display(menu.siteMenu)
            display(self.clientMenu)

        def btnTestClicked(b):
            with self.out:
                display(widgets.HBox([self.btnMenu, btnMenu, btnMenu]))

        def backToMenu(b):
            menu.out.clear_output(wait=True)
            with menu.out:
                display(menu.siteMenu)
                
        def btnAddLineClicked(b):
            with menu.out:
                display(widgets.HBox([self.btnClient, self.btnClient, self.btnClient]))
                
        def btnClearClicked(b):
            menu.out.clear_output(wait=True)
            with menu.out:
                display(menu.siteMenu)
                display(self.clientMenu)

        self.btnClient.on_click(backToMenu)
        self.btnNewLine.on_click(btnAddLineClicked)
        self.btnClearOutput.on_click(btnClearClicked)

        self.out

        
class Task:
    def __init__(self):
        self.out = widgets.Output()
        self.btnTask = widgets.Button(description = "btnTask", layout=widgets.Layout(width='120px'))
        self.btnNewLine = widgets.Button(description = "New Line", layout=widgets.Layout(width='120px'))
        self.btnListRecords = widgets.Button(description = "List Records", layout=widgets.Layout(width='120px'))        
        self.btnClearOutput = widgets.Button(description = "Clear Output", layout=widgets.Layout(width='120px'))
        self.btnEditRecord = widgets.Button(description = "Edit Record", layout=widgets.Layout(width='120px'))
        
        self.taskMenu = widgets.HBox([self.btnTask, self.btnNewLine, self.btnListRecords,\
                                       self.btnClearOutput, self.btnEditRecord])
        
        with menu.out:
            menu.out.clear_output(wait=True)
            display(menu.siteMenu)
            display(self.taskMenu)

        def btnTestClicked(b):
            with self.out:
                display(widgets.HBox([self.btnMenu, btnMenu, btnMenu]))

        def backToMenu(b):
            menu.out.clear_output(wait=True)
            with menu.out:
                display(menu.siteMenu)
                
        def btnAddLineClicked(b):
            with menu.out:
                display(widgets.HBox([self.btnTask, self.btnTask, self.btnTask]))
                
        def btnClearClicked(b):
            menu.out.clear_output(wait = True)
            with menu.out:
                display(menu.siteMenu)
                display(self.taskMenu)

        #self.btnMenu.on_click(backToMenu)
        self.btnNewLine.on_click(btnAddLineClicked)
        self.btnClearOutput.on_click(btnClearClicked)

        self.out        


menu = Menu()
menu.out
# Out:
# Output()
